# %%
import matplotlib
from matplotlib import pylab
import pandas as pd

# %%
df = pd.read_csv('../data/amazon_products.csv')
'''
project:
    /data
        csv files
    /notebooks
        .ipynb files
'''
# Out:
# '\nproject:\n    /data\n        csv files\n    /notebooks\n        .ipynb files\n'

# %%
df = df[df['stars'] != 0]

# %%
df.head()
# Out:
#          asin                                              title  \
# 0  B014TMV5YE  Sion Softside Expandable Roller Luggage, Black...
# 1  B07GDLCQXV  Luggage Sets Expandable PC+ABS Durable Suitcas...
# 2  B07XSCCZYG  Platinum Elite Softside Expandable Checked Lug...
# 3  B08MVFKGJM  Freeform Hardside Expandable with Double Spinn...
# 4  B01DJLKZBA  Winfield 2 Hardside Expandable Luggage with Sp...
#
#                                               imgUrl  \
# 0  https://m.media-amazon.com/images/I/815dLQKYIY...
# 1  https://m.media-amazon.com/images/I/81bQlm7vf6...
# 2  https://m.media-amazon.com/images/I/71EA35zvJB...
# 3  https://m.media-amazon.com/images/I/91k6NYLQyI...
# 4  https://m.media-amazon.com/images/I/61NJoaZcP9...
#
#                              productURL  stars  reviews   price  listPrice  \
# 0  https://www.amazon.com/dp/B014TMV5YE    4.5        0  139.99       0.00
# 1  https://www.amazon.com/dp/B07GDLCQXV    4.5        0  169.99     209.99
# ...

# %%
df.columns
# Out:
# Index(['asin', 'title', 'imgUrl', 'productURL', 'stars', 'reviews', 'price',
#        'listPrice', 'category_id', 'isBestSeller', 'boughtInLastMonth'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1295314 entries, 0 to 1426336
# Data columns (total 11 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   asin               1295314 non-null  str
#  1   title              1295313 non-null  str
#  2   imgUrl             1295314 non-null  str
#  3   productURL         1295314 non-null  str
#  4   stars              1295314 non-null  float64
#  5   reviews            1295314 non-null  int64
#  6   price              1295314 non-null  float64
#  7   listPrice          1295314 non-null  float64
#  8   category_id        1295314 non-null  int64
#  9   isBestSeller       1295314 non-null  bool
#  10  boughtInLastMonth  1295314 non-null  int64
# dtypes: bool(1), float64(3), int64(3), str(4)
# memory usage: 109.9 MB

# %%
df.isnull().sum()
# Out:
# asin                 0
# title                1
# imgUrl               0
# productURL           0
# stars                0
# reviews              0
# price                0
# listPrice            0
# category_id          0
# isBestSeller         0
# boughtInLastMonth    0
# dtype: int64

# %%
df['isBestSeller'].value_counts()
# Out:
# isBestSeller
# False    1286833
# True        8481
# Name: count, dtype: int64

# %%
removed_columns = ['asin', 'imgUrl', 'productURL']
model = df.drop(columns=removed_columns)
model = model.dropna() #remove any rows with null values
model = model[model['reviews'] > 0] # remove products with 0 reviews

# %%
model.info()
model.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1295313 entries, 0 to 1426336
# Data columns (total 8 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   title              1295313 non-null  str
#  1   stars              1295313 non-null  float64
#  2   reviews            1295313 non-null  int64
#  3   price              1295313 non-null  float64
#  4   listPrice          1295313 non-null  float64
#  5   category_id        1295313 non-null  int64
#  6   isBestSeller       1295313 non-null  bool
#  7   boughtInLastMonth  1295313 non-null  int64
# dtypes: bool(1), float64(3), int64(3), str(1)
# memory usage: 80.3 MB
# title                0
# stars                0
# reviews              0
# price                0
# listPrice            0
# category_id          0
# isBestSeller         0
# boughtInLastMonth    0
# dtype: int64

# %%
data = model.drop(columns=['isBestSeller', 'title'])
label = model['isBestSeller'] # metric for "successful" product

# %%
model.to_csv('../data/amazon_preprocessed.csv', index = False)
